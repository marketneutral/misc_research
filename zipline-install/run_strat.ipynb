# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# %load_ext zipline

# %%
rcParams['figure.figsize'] = 10, 5

# %%
# %%time
# %%capture
# %%zipline --start 2016-1-1 --end 2018-1-1 -b csvdir -o outfile.pickle

from zipline.api import symbol, order_target_percent, record

def handle_data(context, data):
    order_target_percent(symbol('US1'), 1.0)
    record(US1=data[symbol('US1')].price)
# Out:
# CPU times: user 1.18 s, sys: 75.8 ms, total: 1.26 s
# Wall time: 1.27 s

# %%
df = pd.read_pickle('outfile.pickle')

# %%
df.pnl.plot();
