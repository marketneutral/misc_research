# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams

plt.style.use('seaborn')

rcParams['figure.figsize'] = 12, 6
import pandas as pd

# %%
df = pd.read_pickle('algo.pickle')

# %%
df.tail(1).T
# Out:
#                                                  2015-12-29 21:00:00+00:00
# algo_volatility                                                   0.107325
# algorithm_period_return                                          -0.102433
# alpha                                                                 None
# benchmark_period_return                                                  0
# benchmark_volatility                                                  None
# beta                                                                  None
# capital_used                                                             0
# daily_95_1d_var                                                 -0.0106247
# daily_99_1d_var                                                  -0.016543
# ending_cash                                                    1.76874e+07
# ending_exposure                                                -8.7117e+06
# ...

# %%
df.daily_95_1d_var.plot(title='1d 95% VaR', legend=True);
df.daily_99_1d_var.plot(title='1d 95% VaR', legend=True);

# %%
df.portfolio_value.plot()

# %%
df.pnl.plot()

# %%
df.orders.loc['2012-01-31 21:00:00+00:00']
# Out:
# [{'amount': -68758,
#   'commission': 0,
#   'created': Timestamp('2012-01-31 21:00:00+0000', tz='UTC'),
#   'dt': Timestamp('2012-01-31 21:00:00+0000', tz='UTC'),
#   'filled': 0,
#   'id': '2ce4bd5116524ec7a934e4ebdecd0550',
#   'limit': None,
#   'limit_reached': False,
#   'reason': None,
#   'sid': Equity(3 [US1]),
#   'status': 0,
#   'stop': None,
#   'stop_reached': False}]

# %%
df.orders.loc['2012-02-01 21:00:00+00:00']
# Out:
# [{'amount': -68758,
#   'commission': 0,
#   'created': Timestamp('2012-01-31 21:00:00+0000', tz='UTC'),
#   'dt': Timestamp('2012-02-01 21:00:00+0000', tz='UTC'),
#   'filled': -68758,
#   'id': '2ce4bd5116524ec7a934e4ebdecd0550',
#   'limit': None,
#   'limit_reached': False,
#   'reason': None,
#   'sid': Equity(3 [US1]),
#   'status': 1,
#   'stop': None,
#   'stop_reached': False}]
