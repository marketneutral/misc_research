# %%
# import Pkg; Pkg.add("Plots")

# %%
using Plots
using Random

# %%
Plots.default(legend=false)
Random.seed!(42);

# %%
plot(1:100, rand(100))

# %%
@time begin

a = plot(sin, 0, 2pi)
b = plot(cos, 0, 2pi)
c = histogram(randn(1000), alpha=0.75)

plot(a, b, c, layout=(1,3), size=(750, 250))

end
# Out:
#   0.005663 seconds (20.87 k allocations: 1.495 MiB)

# %%
scatter(randn(1000), randn(1000) .- 1, alpha=0.5)
scatter!(randn(1000) .+ 1.5, randn(1000) .+ 2.5, alpha=0.5)
scatter!(randn(1000) .- 2.5, randn(1000), alpha=0.3)
